# %%
import pandas as pd
import numpy as np
import json
import requests
pd.set_option('precision', 0)

# %%
# %%capture

from tqdm import tqdm_notebook as tqdm
from tqdm import tnrange
tqdm().pandas()

# %%
df = pd.read_csv("links.csv")

# %%
df
# Out:
#       movieId   imdbId  tmdbId
# 0           1   114709     862
# 1           2   113497    8844
# 2           3   113228   15602
# 3           4   114885   31357
# 4           5   113041   11862
# ...       ...      ...     ...
# 9737   193581  5476944  432131
# 9738   193583  5914996  445030
# 9739   193585  6397426  479308
# 9740   193587  8391976  483455
# 9741   193609   101726   37891
#
# [9742 rows x 3 columns]

# %%
link_list = df['tmdbId'].fillna(0).tolist()

# %%
link_list
# Out:
# [862.0,
#  8844.0,
#  15602.0,
#  31357.0,
#  11862.0,
#  949.0,
#  11860.0,
#  45325.0,
#  9091.0,
#  710.0,
#  9087.0,
#  12110.0,
#  21032.0,
#  10858.0,
#  1408.0,
#  524.0,
#  4584.0,
#  5.0,
#  9273.0,
#  11517.0,
#  8012.0,
#  1710.0,
#  9691.0,
#  12665.0,
#  451.0,
#  16420.0,
#  9263.0,
#  17015.0,
#  902.0,
#  37557.0,
#  9909.0,
#  63.0,
#  9598.0,
#  687.0,
#  33689.0,
#  9603.0,
#  34615.0,
#  31174.0,
#  11443.0,
#  35196.0,
#  9312.0,
#  577.0,
#  11861.0,
#  807.0,
#  10530.0,
#  8391.0,
#  629.0,
#  11448.0,
#  49133.0,
#  26441.0,
#  97406.0,
#  9089.0,
#  11010.0,
#  11359.0,
#  17182.0,
#  2054.0,
#  10607.0,
#  19760.0,
#  9536.0,
#  11525.0,
#  4482.0,
#  10634.0,
#  755.0,
#  11859.0,
#  28387.0,
#  48750.0,
#  20927.0,
#  36929.0,
#  9102.0,
#  124626.0,
#  27526.0,
#  9623.0,
#  46785.0,
#  400.0,
#  880.0,
#  146599.0,
#  8447.0,
#  10534.0,
#  17414.0,
#  13997.0,
#  2086.0,
#  9095.0,
#  12158.0,
#  9283.0,
#  9208.0,
#  40154.0,
#  406.0,
#  63076.0,
# ...

# %%
link_list = list(map(int,link_list))

# %%
len_list = len(link_list)

# %%
plot_df = pd.DataFrame(columns=['tmdb_id', 'plot'])
plot_df
# Out:
# Empty DataFrame
# Columns: [tmdb_id, plot]
# Index: []

# %%
for num in tqdm(link_list[8712:]):
    if num == 0:
        plot_df = plot_df.append({'tmdb_id': num, 'plot' : "not applicable"} , ignore_index=True)
    else:
        url = 'https://api.themoviedb.org/3/movie/'+ str(num) +'?api_key=4b1c7165172d96b4531d9d50f7464660&language=en-US'
        response = requests.get(url)
        data = response.json()
        plot = data.get('overview')
        plot_df = plot_df.append({'tmdb_id': num, 'plot' : plot} , ignore_index=True)

# %%
plot_df
# Out:
#      tmdb_id                                               plot
# 0        862  Led by Woody, Andy's toys live happily in his ...
# 1       8844  When siblings Judy and Peter discover an encha...
# 2      15602  A family wedding reignites the ancient feud be...
# 3      31357  Cheated on, mistreated and stepped on, the wom...
# 4      11862  Just when George Banks has recovered from his ...
# ...      ...                                                ...
# 9737  432131  Ciel learns of a "Aurora Society", that is rum...
# 9738  445030  In ancient Disboard, Riku is an angry, young w...
# 9739  479308  A woman deals with the toxic water scandal in ...
# 9740  483455  Power users around the world are suddenly comm...
# 9741   37891  Outrageous, misogynistic and vulgar-to-the-max...
#
# [9742 rows x 2 columns]

# %%
plot_df.to_csv("plot.csv")
